# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from pathlib import Path
import os, sys, datetime, time, random, fnmatch, math, re
import matplotlib.pyplot as plt


import torchvision.transforms as tvtransforms

# Torch
import torch
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split

# MTANN
import MTANN
from torchviz import make_dot
import datasets, transforms

flag_verbose = False

path_to_save = os.path.join('.')


# Data
root_directory = "D:/data/JSRT/"
path_to_source_images = os.path.join(root_directory, "JSRT")
path_to_target_images = os.path.join(root_directory, "BSE_JSRT")

image_spatial_size=(512,512)
key_source, key_boneless = "source", "boneless"
validation_test_length = 10

# Datasets
discriminator_keys_images = [key_source, key_boneless]
ds = datasets.JSRT_CXR( path_to_source_images, path_to_target_images, 
                       transform=tvtransforms.Compose([
                             transforms.RescalingNormalisation(discriminator_keys_images,(0,1)),
                             transforms.RandomIntensityComplement(discriminator_keys_images, probability=0.5),
                             transforms.Rescale(image_spatial_size, discriminator_keys_images),
                             ]))
lengths=(len(ds)-validation_test_length, validation_test_length)
print(lengths)
ds_training, ds_val = random_split(ds, lengths)

fixed_sample = next(iter(ds_val))
plt.imshow(fixed_sample[key_source])

## Code for putting things on the GPU
ngpu = 1 #torch.cuda.device_count()
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
print(device)
if (torch.cuda.is_available() and ngpu > 0):
    print(torch.cuda.get_device_name(torch.cuda.current_device()))
# Out:
# (231, 10)
# cpu

# %%
# Networks
netHR = MTANN.linearOutputANN(first_layer=81, second_layer=20)
netMR = MTANN.linearOutputANN(first_layer=81, second_layer=20)
netLR = MTANN.linearOutputANN(first_layer=81, second_layer=20)
# Loss
criterion = nn.L1Loss()
# Optimiser
optimiserHR = optim.SGD(netHR.parameters(), lr=0.001)
optimiserMR = optim.SGD(netMR.parameters(), lr=0.001)
optimiserLR = optim.SGD(netLR.parameters(), lr=0.001)

# %%
from skimage.metrics import structural_similarity as ssim

ovs = MTANN.OverlappingSubregions(key_source, key_boneless,9,1)

iters, flag_break = 0,False
reals_shown = 0
ssim_list = []
for sample_count, sample in enumerate(ds_training):
    
    #if sample_count > 4:
    #    print("Complete debugging")
    #    break
    
    preprocessing = MTANN.dataPreprocessing(sample, discriminator_keys_images)
    
    iters=0
    for ii, data in enumerate(ovs.execute(preprocessing.LR)):
        # Subregions are the training data input
        # Target_pixels are the training data target outputs
        subregion, target_pixel, center_pixel = data
        
        #print(subregion.shape)
        #print(target_pixel)
        
        optimiserLR.zero_grad()
        outputs = netLR(subregion)
        loss = criterion(outputs, target_pixel)
        loss.backward()
        optimiserLR.step()
        iters+=1
    reals_shown += iters
    if flag_verbose:
        print("LR Training Complete.")
        print("Reals shown: {}".format(reals_shown))
    MTANN.save_model(os.path.join(path_to_save,'netLR.pt'), netLR, optimiserLR, loss, reals_shown)
    
    iters=0
    for ii, data in enumerate(ovs.execute(preprocessing.MR)):
        # Subregions are the training data input
        # Target_pixels are the training data target outputs
        subregion, target_pixel, center_pixel = data
        
        optimiserMR.zero_grad()
        outputs = netMR(subregion)
        loss = criterion(outputs, target_pixel)
        loss.backward()
        optimiserMR.step()
        iters+=1
    reals_shown += iters
    if flag_verbose:
        print("MR Training Complete.")
        print("Reals shown: {}".format(reals_shown))
    MTANN.save_model(os.path.join(path_to_save,'netMR.pt'), netMR, optimiserMR, loss, reals_shown)
    
    iters = 0
    for ii, data in enumerate(ovs.execute(preprocessing.HR)):
        # Subregions are the training data input
        # Target_pixels are the training data target outputs
        subregion, target_pixel, center_pixel = data
        
        optimiserHR.zero_grad()
        outputs = netHR(subregion)
        loss = criterion(outputs, target_pixel)
        loss.backward()
        optimiserHR.step()
        iters+=1
    reals_shown += iters
    if flag_verbose:
        print("HR Training Complete.")
        print("Reals shown: {}".format(reals_shown))
    MTANN.save_model(os.path.join(path_to_save,'netHR.pt'), netHR, optimiserHR, loss, reals_shown)
    
    print("Number of radiology images trained on: {} ; number of reals shown: {}".format(sample_count, reals_shown))
    
    # Reconstruction of images to validate
    validation_sample = next(iter(ds_val))
    reconstruction = MTANN.ImageReconstruction(validation_sample, key_source, key_boneless=None, matrix_size=9, stride=1)
    image, image_from_LR , image_from_MR , image_from_HR = reconstruction.reconstruct_multiresolution(netHR, netMR, netLR)
    image = (image - np.amin(image))/(np.amax(image) - np.amin(image)) # rescale to [0,1]
    ssim_list.append(ssim(image, validation_sample[key_boneless]))
# Out:
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 0 ; number of reals shown: 344064
# C:\Users\nfdlam\.conda\envs\AI\lib\site-packages\ipykernel_launcher.py:80: UserWarning: Inputs have mismatched dtype.  Setting data_range based on im1.dtype.
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 1 ; number of reals shown: 688128
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 2 ; number of reals shown: 1032192
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 3 ; number of reals shown: 1376256
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 4 ; number of reals shown: 1720320
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 5 ; number of reals shown: 2064384
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 6 ; number of reals shown: 2408448
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 7 ; number of reals shown: 2752512
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 8 ; number of reals shown: 3096576
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 9 ; number of reals shown: 3440640
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 10 ; number of reals shown: 3784704
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 11 ; number of reals shown: 4128768
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 12 ; number of reals shown: 4472832
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 13 ; number of reals shown: 4816896
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 14 ; number of reals shown: 5160960
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 15 ; number of reals shown: 5505024
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 16 ; number of reals shown: 5849088
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 17 ; number of reals shown: 6193152
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 18 ; number of reals shown: 6537216
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 19 ; number of reals shown: 6881280
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 20 ; number of reals shown: 7225344
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 21 ; number of reals shown: 7569408
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 22 ; number of reals shown: 7913472
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 23 ; number of reals shown: 8257536
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 24 ; number of reals shown: 8601600
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 25 ; number of reals shown: 8945664
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 26 ; number of reals shown: 9289728
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 27 ; number of reals shown: 9633792
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 28 ; number of reals shown: 9977856
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 29 ; number of reals shown: 10321920
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 30 ; number of reals shown: 10665984
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 31 ; number of reals shown: 11010048
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 32 ; number of reals shown: 11354112
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 33 ; number of reals shown: 11698176
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 34 ; number of reals shown: 12042240
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 35 ; number of reals shown: 12386304
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 36 ; number of reals shown: 12730368
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 37 ; number of reals shown: 13074432
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 38 ; number of reals shown: 13418496
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 39 ; number of reals shown: 13762560
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 40 ; number of reals shown: 14106624
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 41 ; number of reals shown: 14450688
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 42 ; number of reals shown: 14794752
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 43 ; number of reals shown: 15138816
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 44 ; number of reals shown: 15482880
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 45 ; number of reals shown: 15826944
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 46 ; number of reals shown: 16171008
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 47 ; number of reals shown: 16515072
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 48 ; number of reals shown: 16859136
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 49 ; number of reals shown: 17203200
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 50 ; number of reals shown: 17547264
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 51 ; number of reals shown: 17891328
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 52 ; number of reals shown: 18235392
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 53 ; number of reals shown: 18579456
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 54 ; number of reals shown: 18923520
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 55 ; number of reals shown: 19267584
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 56 ; number of reals shown: 19611648
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 57 ; number of reals shown: 19955712
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 58 ; number of reals shown: 20299776
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 59 ; number of reals shown: 20643840
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 60 ; number of reals shown: 20987904
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 61 ; number of reals shown: 21331968
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on:
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 153 ; number of reals shown: 52985856
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 154 ; number of reals shown: 53329920
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 155 ; number of reals shown: 53673984
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 156 ; number of reals shown: 54018048
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 157 ; number of reals shown: 54362112
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 158 ; number of reals shown: 54706176
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 159 ; number of reals shown: 55050240
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 160 ; number of reals shown: 55394304
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 161 ; number of reals shown: 55738368
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 162 ; number of reals shown: 56082432
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 163 ; number of reals shown: 56426496
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 164 ; number of reals shown: 56770560
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 165 ; number of reals shown: 57114624
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 166 ; number of reals shown: 57458688
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 167 ; number of reals shown: 57802752
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 168 ; number of reals shown: 58146816
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 169 ; number of reals shown: 58490880
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 170 ; number of reals shown: 58834944
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 171 ; number of reals shown: 59179008
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 172 ; number of reals shown: 59523072
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 173 ; number of reals shown: 59867136
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 174 ; number of reals shown: 60211200
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 175 ; number of reals shown: 60555264
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 176 ; number of reals shown: 60899328
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 177 ; number of reals shown: 61243392
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 178 ; number of reals shown: 61587456
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 179 ; number of reals shown: 61931520
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 180 ; number of reals shown: 62275584
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 181 ; number of reals shown: 62619648
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 182 ; number of reals shown: 62963712
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 183 ; number of reals shown: 63307776
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 184 ; number of reals shown: 63651840
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 185 ; number of reals shown: 63995904
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 186 ; number of reals shown: 64339968
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 187 ; number of reals shown: 64684032
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 188 ; number of reals shown: 65028096
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 189 ; number of reals shown: 65372160
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 190 ; number of reals shown: 65716224
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 191 ; number of reals shown: 66060288
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 192 ; number of reals shown: 66404352
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 193 ; number of reals shown: 66748416
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 194 ; number of reals shown: 67092480
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 195 ; number of reals shown: 67436544
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 196 ; number of reals shown: 67780608
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 197 ; number of reals shown: 68124672
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 198 ; number of reals shown: 68468736
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 199 ; number of reals shown: 68812800
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 200 ; number of reals shown: 69156864
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 201 ; number of reals shown: 69500928
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 202 ; number of reals shown: 69844992
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 203 ; number of reals shown: 70189056
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 204 ; number of reals shown: 70533120
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 205 ; number of reals shown: 70877184
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 206 ; number of reals shown: 71221248
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 207 ; number of reals shown: 71565312
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 208 ; number of reals shown: 71909376
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 209 ; number of reals shown: 72253440
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 210 ; number of reals shown: 72597504
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 211 ; number of reals shown: 72941568
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 212 ; number of reals shown: 73285632
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 213 ; number of reals shown: 73629696
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 214 ; number of reals shown: 73973760
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 215 ; number of reals shown: 74317824
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 216 ; number of reals shown: 74661888
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 217 ; number of reals shown: 75005952
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 218 ; number of reals shown: 75350016
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 219 ; number of reals shown: 75694080
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 220 ; number of reals shown: 76038144
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 221 ; number of reals shown: 76382208
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 222 ; number of reals shown: 76726272
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 223 ; number of reals shown: 77070336
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 224 ; number of reals shown: 77414400
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 225 ; number of reals shown: 77758464
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 226 ; number of reals shown: 78102528
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 227 ; number of reals shown: 78446592
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 228 ; number of reals shown: 78790656
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 229 ; number of reals shown: 79134720
# Saved File at: .\netLR.pt
# Saved File at: .\netMR.pt
# Saved File at: .\netHR.pt
# Number of radiology images trained on: 230 ; number of reals shown: 79478784

# %%
output_save_directory = "."
plt.plot(ssim_list)
plt.title("SSIM")
plt.xlabel("Radiography Images Shown")
plt.ylabel("SSIM")
plt.savefig(os.path.join(output_save_directory, "SSIM"+".png"))

# %%
a = np.zeros((5,5))
a = np.pad(a,2)
print(a.shape)
# Out:
# (9, 9)
